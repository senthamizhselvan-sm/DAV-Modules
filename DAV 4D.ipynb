# %% [markdown]
# 4 D

# %%
import pandas as pd

from scipy.stats import f_oneway

url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"

uci_diabetes = pd.read_csv(url)
pima_diabetes = pd.read_csv(url).sample(frac=1, random_state=42).reset_index(drop=True)

numerical_columns = ["Glucose", "BloodPressure", "BMI"]

anova_results = {}

for col in numerical_columns:
    f_stat, p_value = f_oneway(
        uci_diabetes[col],
        pima_diabetes[col]
    )

    anova_results[col] = {
        "F-statistic": f_stat,
        "P-value": p_value
    }

anova_df = pd.DataFrame(anova_results).T

print("ANOVA Results")
print(anova_df)
# Out:
# ANOVA Results
#                 F-statistic  P-value
# Glucose        0.000000e+00      1.0
# BloodPressure  0.000000e+00      1.0
# BMI            2.115136e-33      1.0
