# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Load Pima Diabetes Dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

columns = [
    "Pregnancies", "Glucose", "BloodPressure", "SkinThickness",
    "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"
]

pima_diabetes = pd.read_csv(url, names=columns)

# Duplicate dataset as UCI dataset for experiment
uci_diabetes = pima_diabetes.copy()

print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())

print("\nPima Diabetes Dataset Sample:")
print(pima_diabetes.head())
# Out:
# UCI Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Pima Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# ...

# %%
numerical_columns = [
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age"
]

def univariate_analysis(df):
    stats = {}

    for col in numerical_columns:
        stats[col] = {
            "Mean": df[col].mean(),
            "Median": df[col].median(),
            "Mode": df[col].mode()[0],
            "Variance": df[col].var(),
            "Standard Deviation": df[col].std(),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }

    return pd.DataFrame(stats).T

# %%
uci_stats = univariate_analysis(uci_diabetes)
pima_stats = univariate_analysis(pima_diabetes)

print("UCI Diabetes Dataset Statistics")
print(uci_stats)

print("\nPima Diabetes Dataset Statistics")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Statistics
#                                 Mean    Median    Mode      Variance  \
# Glucose                   120.894531  117.0000  99.000   1022.248314
# BloodPressure              69.105469   72.0000  70.000    374.647271
# SkinThickness              20.536458   23.0000   0.000    254.473245
# Insulin                    79.799479   30.5000   0.000  13281.180078
# BMI                        31.992578   32.0000  32.000     62.159984
# DiabetesPedigreeFunction    0.471876    0.3725   0.254      0.109779
# Age                        33.240885   29.0000  22.000    138.303046
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            31.972618  0.173414  0.628813
# BloodPressure                      19.355807 -1.840005  5.138691
# SkinThickness                      15.952218  0.109159 -0.524494
# Insulin                           115.244002  2.267810  7.159575
# ...
